# %%
import sys
import os

sys.path.append(os.path.abspath("./core"))

# %%
from cnn import MyCNN
from datalist import data_list
from core import core

# %%
core.training
# Out:
# <function training.training(model, dataloader_dict, optimizer, loss_ln, device, best_acc, start_epoch=None, num_epochs=None)>
